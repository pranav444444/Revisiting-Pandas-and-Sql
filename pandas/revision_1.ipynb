# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data={'name':['Sumit','Rahul','Ankit'],
      'age':[25,30,35],
      'salary':[25000,30000,35000]
      }

df=pd.DataFrame(data)
df
# Out:
#     name  age  salary
# 0  Sumit   25   25000
# 1  Rahul   30   30000
# 2  Ankit   35   35000

# %%
df=pd.read_csv('D:\Revision-Pandas_SQL\data\orders.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\Mukesh\AppData\Local\Temp\ipykernel_33860\2827182933.py:1: SyntaxWarning: invalid escape sequence '\R'
#   df=pd.read_csv('D:\Revision-Pandas_SQL\data\orders.csv')
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# ...

# %%
df.tail()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 45  Central  OFF-BI-10003291  Office Supplies   17.5         2     8.2
# 46  Central  OFF-ST-10001713  Office Supplies  212.0         4     8.5
# 47     East  TEC-AC-10002167       Technology   45.0         3     5.0
# 48     East  TEC-PH-10003988       Technology   21.8         2     6.1
# 49  Central  OFF-BI-10004410  Office Supplies   38.2         6    18.0

# %%
df.head(10)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %%
df.tail(10)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 40  Central  TEC-PH-10000486       Technology  371.2         4    41.8
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df.shape
# Out:
# (50, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %%
df.describe() #to show statistical summary
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %%
#to rename columns
df.rename(columns={'customer_id':'customer_key'},inplace=True)
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_key',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %%
#to rename columns
df.rename(columns={'customer_key':'customer_id'},inplace=True)
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %% [markdown]
# # Selection of columns

# %%
# col=['order_id','order_date','ship_date']
# df[col]
df_new=df[['order_id','order_date','ship_date']]
df_new.head()
# Out:
#          order_id  order_date   ship_date
# 0  CA-2020-152156  08-11-2020  11-11-2020
# 1  CA-2020-152156  08-11-2020  11-11-2020
# 2  CA-2020-138688  12-06-2020  16-06-2020
# 3  US-2019-108966  11-10-2019  18-10-2019
# 4  US-2019-108966  11-10-2019  18-10-2019

# %%
df['order_id']
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %%
df.order_id
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Series: DataFrame with single column

# %%
df_new_1=df['order_id']

# %%
df_new_1
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %%
type(df_new_1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Selectign rows,columns :loc,iloc

# %% [markdown]
# ## iloc:index location - > fetches rowa and columns purely based on indexes

# %%
#select rows and columns based on index
df.iloc[0:5] #iloc=index location
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.iloc[3:5]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.iloc[3:]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 12  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 14  US-2019-118983  22-11-2019  26-11-2019  Standard Class    HP-14815
# ...

# %%
df.iloc[:4]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0

# %%
df.iloc[::-1]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 39  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 38  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# ...

# %%
#to fetch only a particular rows.. pass the list of the indexes
df.iloc[[3,5,18]]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 18  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925   West
#
#          product_id         category  sales  quantity  profit
# 3   FUR-TA-10000577        Furniture  957.6         5  -383.0
# 5   FUR-FU-10001487        Furniture   48.9         7    14.2
# 18  OFF-AR-10003056  Office Supplies    8.6         2     2.5

# %%
#we can also specify which columns we want
df.iloc[[2,5,8],0:4]
# Out:
#          order_id  order_date   ship_date       ship_mode
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class

# %%
df.iloc[[2,5,8],[5,6]]
# Out:
#   region       product_id
# 2   West  OFF-LA-10000240
# 5   West  FUR-FU-10001487
# 8   West  OFF-BI-10003910

# %% [markdown]
# ## loc : fetches rows based on index values(not index location like iloc),and we can mention columns names too(in iloc we were only able to give index locations)

# %%
df_new_2=df.loc[0:10,['order_id','order_date','sales']]
df_new_2
# Out:
#           order_id  order_date   sales
# 0   CA-2020-152156  08-11-2020   262.0
# 1   CA-2020-152156  08-11-2020   731.9
# 2   CA-2020-138688  12-06-2020    14.6
# 3   US-2019-108966  11-10-2019   957.6
# 4   US-2019-108966  11-10-2019    22.4
# 5   CA-2018-115812  09-06-2018    48.9
# 6   CA-2018-115812  09-06-2018     7.3
# 7   CA-2018-115812  09-06-2018   907.2
# 8   CA-2018-115812  09-06-2018    18.5
# 9   CA-2018-115812  09-06-2018   114.9
# 10  CA-2018-115812  09-06-2018  1706.2

# %%
df.set_index('order_id',inplace=True)

# %%
df
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.set_index('order_id',inplace=True)
df
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.loc['CA-2020-152156']
# Out:
#                 order_date   ship_date     ship_mode customer_id region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South
#
#                      product_id   category  sales  quantity  profit
# order_id
# CA-2020-152156  FUR-BO-10001798  Furniture  262.0         2    41.9
# CA-2020-152156  FUR-CH-10000454  Furniture  731.9         3   219.6

# %%
df.loc['CA-2020-152156',['order_date','sales']]
# Out:
#                 order_date  sales
# order_id
# CA-2020-152156  08-11-2020  262.0
# CA-2020-152156  08-11-2020  731.9

# %%
df.loc['CA-2020-152156','order_date':'region']
# Out:
#                 order_date   ship_date     ship_mode customer_id region
# order_id
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520  South

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# #continue from 37:00
